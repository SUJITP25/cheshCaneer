# %%
import pandas as pd 
import pymongo
df = pd.read_csv("data.csv")
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# Data should be added in the key-value form in database 

data = df.to_dict(orient="records")

# %%
DB_NAME = "proj1"
COLLECTION_NAME="proj1_data"
COLLECTION_URL="mongodb+srv://gujaratstory123:Sujit2518@cluster0.afqy9fh.mongodb.net/"

#Delete Crdentials before pushing it to the github

# %%
client = pymongo.MongoClient(COLLECTION_URL)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)

# %%
type(rec)
# Out:
# pymongo.results.InsertManyResult

# %%
records = collection.find()

# %%
records

# %%
list(records)
# Out:
# [{'_id': ObjectId('6840f4c99e5ff4f28592e2ae'),
#   'id': 1,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 40454.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 217,
#   'Response': 1},
#  {'_id': ObjectId('6840f4c99e5ff4f28592e2af'),
#   'id': 2,
#   'Gender': 'Male',
#   'Age': 76,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33536.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 183,
#   'Response': 0},
#  {'_id': ObjectId('6840f4c99e5ff4f28592e2b0'),
#   'id': 3,
#   'Gender': 'Male',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38294.0,
#   'Policy_Sales_Channel': 26.0,
# ...
